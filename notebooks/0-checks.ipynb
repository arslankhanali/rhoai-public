# %% [markdown]
# # Test properties
# Lets see what available to this notebook

# %% [markdown]
# ## Nvidia - Available in CUDA notebook

# %%
# !nvidia-smi
# Out:
# Tue Apr 28 08:39:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.20             Driver Version: 580.126.20     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   26C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Available Connections and env variables

# %%
import os
for k in ["AWS_ACCESS_KEY_ID", "AWS_SECRET_ACCESS_KEY", "AWS_S3_ENDPOINT", "AWS_S3_BUCKET", "HF_TOKEN"]:
    v = os.environ.get(k, "")
    ok = bool(v) and v not in ("<YOUR_HF_TOKEN>",)
    show = f"{v[:4]}…" if (v and ("SECRET" in k or k == "HF_TOKEN")) else (v or "(missing)")
    print(f"{'OK' if ok else '!!'}  {k}: {show}")
# Out:
# OK  AWS_ACCESS_KEY_ID: minio
# OK  AWS_SECRET_ACCESS_KEY: mini…
# OK  AWS_S3_ENDPOINT: http://minio-service.minio.svc.cluster.local:9000
# OK  AWS_S3_BUCKET: models
# OK  HF_TOKEN: hf_M…

# %%
#!env

# %% [markdown]
# ## Download important packages

# %%
# %pip install -q boto3 huggingface_hub
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !ln -sf /opt/app-root/src/rhoai-public/notebooks/minio-binaries/mc /opt/app-root/bin/mc
# !mc alias set myminio "$AWS_S3_ENDPOINT" "$AWS_ACCESS_KEY_ID" "$AWS_SECRET_ACCESS_KEY"
# !mc ls myminio
# Out:
# ]11;?\mc: Configuration written to `/opt/app-root/src/.mc/config.json`. Please update your access credentials.
# mc: Successfully created `/opt/app-root/src/.mc/share`.
# mc: Initialized share uploads `/opt/app-root/src/.mc/share/uploads.json` file.
# mc: Initialized share downloads `/opt/app-root/src/.mc/share/downloads.json` file.
# Added `myminio` successfully.
# ]11;?\

# %%
# !mc ls myminio
# Out:
# ]11;?\[2026-04-28 08:33:41 UTC]     0B models/
